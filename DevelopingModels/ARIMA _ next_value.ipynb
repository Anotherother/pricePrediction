# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.tools.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_model import ARIMA, ARMAResults

import datetime
import sys
import seaborn as sns
import statsmodels
import statsmodels.stats.diagnostic as diag
from statsmodels.tsa.stattools import adfuller
from arch import arch_model
from scipy.stats.mstats import normaltest
from matplotlib.pyplot import acorr
# %matplotlib inline
import quandl

import sqlalchemy

import seaborn as sns
from pylab import rcParams

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale = 1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42

WINDOW = 22

# %%
def connect(user, password, db, host: str, port: int, echo=True):
    url = 'postgresql+psycopg2://{}:{}@{}:{}/{}'
    url = url.format(user, password, host, port, db)
    eng = sqlalchemy.create_engine(url, client_encoding='utf8', echo=echo)
    meta = sqlalchemy.MetaData(bind=eng)
    return eng, meta

def get_data_frame(pair: str = 'USDT_BTC', exchange: str = 'poloniex') -> pd.DataFrame:
    """Метод стягивания данных из базы в датафрейм.
    По умолчанию тянет все значения в базе для валютной пары доллар биткоин.
    Список спаршенных пар смотри в таблице Pair
    Цепляться будет отовсюду где есть инетрнет"""
    engine, meta = connect(user='postgres', password='password', db='btccandles', host='94.230.125.199', port=16432)
    df = pd.read_sql_query(
        "SELECT date, time, open, close, low, high, volume, pair.\"name\""
        "FROM candlestick, pair WHERE candlestick.pair_id = pair.id AND pair.id IN ("
        "SELECT pair.id FROM pair, exchange WHERE ("
        "SELECT pair.id FROM pair WHERE pair.name = '" + pair +
        "') = pair.alias_id AND pair.exchange_id = (SELECT exchange.id FROM exchange WHERE exchange.\"name\" = '" + exchange + "')) ORDER BY candlestick.date;",
        con=engine)
    return df


from statsmodels.tsa.stattools import adfuller

def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=12)
    rolstd = pd.rolling_std(timeseries, window=12)

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
df = get_data_frame("USDT_ETH")
df = df[:-1]
ts = df[['date','close']][:-1]
# Out:
# 2017-07-26 11:36:27,776 INFO sqlalchemy.engine.base.Engine select version()
# 2017-07-26 11:36:27,777 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:36:27,778 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2017-07-26 11:36:27,779 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:36:27,781 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2017-07-26 11:36:27,782 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:36:27,783 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2017-07-26 11:36:27,784 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:36:27,785 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2017-07-26 11:36:27,786 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:36:27,787 INFO sqlalchemy.engine.base.Engine SELECT date, time, open, close, low, high, volume, pair."name"FROM candlestick, pair WHERE candlestick.pair_id = pair.id AND pair.id IN (SELECT pair.id FROM pair, exchange WHERE (SELECT pair.id FROM pair WHERE pair.name = 'USDT_ETH') = pair.alias_id AND pair.exchange_id = (SELECT exchange.id FROM exchange WHERE exchange."name" = 'poloniex')) ORDER BY candlestick.date;
# 2017-07-26 11:36:27,788 INFO sqlalchemy.engine.base.Engine {}

# %%
########
ts_log = np.log(ts.close)
plt.plot(ts_log)
plt.title('Log-scale represetation')
plt.show()

######
moving_avg = pd.rolling_mean(ts_log,12)
plt.plot(ts_log)
plt.title('Moving-average represetation')
plt.plot(moving_avg, color='red')
plt.show()
# Out:
# /root/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()

# %%
expwighted_avg = pd.ewma(ts_log, halflife=5)
plt.plot(ts_log)
plt.plot(expwighted_avg, color='red')
# Out:
# /root/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(halflife=5,min_periods=0,adjust=True,ignore_na=False).mean()
#   """Entry point for launching an IPython kernel.

# %%
ts_log_ewma_diff = ts_log - expwighted_avg
test_stationarity(ts_log_ewma_diff)
# Out:
# /root/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:29: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# /root/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:30: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.115807
# p-value                          0.000912
# #Lags Used                       9.000000
# Number of Observations Used    706.000000
# Critical Value (1%)             -3.439646
# Critical Value (5%)             -2.865643
# Critical Value (10%)            -2.568955
# dtype: float64

# %%
# Differencing
ts_log_diff = ts_log - ts_log.shift()
plt.plot(ts_log_diff)

# %%
ts_log_diff.dropna(inplace=True)
test_stationarity(ts_log_diff)
# Out:
# /root/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:29: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# /root/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:30: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                -9.413630e+00
# p-value                        5.746554e-16
# #Lags Used                     6.000000e+00
# Number of Observations Used    7.080000e+02
# Critical Value (1%)           -3.439620e+00
# Critical Value (5%)           -2.865631e+00
# Critical Value (10%)          -2.568948e+00
# dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(ts_log.values, freq=12)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
ts_log_decompose = residual

# %%
#ACF and PACF plots:
from statsmodels.tsa.stattools import acf, pacf

lag_acf = acf(ts_log_diff, nlags=40)
lag_pacf = pacf(ts_log_diff, nlags=40, method='ols')

#Plot ACF: 
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')

# %%
#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(ts_log.dropna().as_matrix(), order=(2, 1, 0))  
results_ARIMA = model.fit()  

plt.plot(ts_log_diff)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_ARIMA.fittedvalues-ts_log_diff)**2))

# %%
numofsteps = 3
stepahead = results_ARIMA.forecast(numofsteps)[0]
ferrors = results_ARIMA.forecast(numofsteps)[2]

print ('%s Steps Ahead Forecast  is:' % numofsteps, np.exp(stepahead))
# Out:
# 3 Steps Ahead Forecast  is: [ 228.24949154  230.71189494  232.39331227]

# %%
df = get_data_frame('USDT_ETH')
print (df.tail())
# Out:
# 2017-07-26 11:33:57,161 INFO sqlalchemy.engine.base.Engine select version()
# 2017-07-26 11:33:57,162 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:33:57,164 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2017-07-26 11:33:57,164 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:33:57,166 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2017-07-26 11:33:57,167 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:33:57,168 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2017-07-26 11:33:57,169 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:33:57,171 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2017-07-26 11:33:57,171 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:33:57,173 INFO sqlalchemy.engine.base.Engine SELECT date, time, open, close, low, high, volume, pair."name"FROM candlestick, pair WHERE candlestick.pair_id = pair.id AND pair.id IN (SELECT pair.id FROM pair, exchange WHERE (SELECT pair.id FROM pair WHERE pair.name = 'USDT_ETH') = pair.alias_id AND pair.exchange_id = (SELECT exchange.id FROM exchange WHERE exchange."name" = 'poloniex'));
# 2017-07-26 11:33:57,173 INFO sqlalchemy.engine.base.Engine {}
#            date      time        open       close         low    high  \
# 713  2017-07-21  07:00:00  226.886817  216.572720  210.000000  240.00
# 714  2017-07-22  07:00:00  216.572720  232.500000  215.360000  237.19
# 715  2017-07-23  07:00:00  233.000000  227.627775  218.077812  236.50
# 716  2017-07-25  07:00:00  226.800000  203.000000  190.000000  227.42
# 717  2017-07-24  07:00:00  227.700000  226.800000  224.000000  231.40
#
#            volume      name
# 713  3.354902e+07  USDT_ETH
# 714  2.068682e+07  USDT_ETH
# 715  1.720380e+07  USDT_ETH
# 716  3.942362e+07  USDT_ETH
# 717  8.850822e+06  USDT_ETH

# %%
from statsmodels.tsa.arima_model import ARIMA

def testARIMA(currency, numsteps):
    df = get_data_frame(currency)
 #   df = df[:-1]
    ts = df[['date','close']][:-1]
    print (df.tail())
    print (ts.tail())
    ts_log = np.log(ts.close)
    model = ARIMA(ts_log.dropna().as_matrix(), order=(2, 1, 0))  
    results_ARIMA = model.fit()  
    stepahead = results_ARIMA.forecast(numsteps)[0]
    
    print ('%s Steps Ahead Forecast  is:' % numsteps, np.exp(stepahead)) 
    
testARIMA("USDT_ETH", 3)
# Out:
# 2017-07-26 11:39:56,277 INFO sqlalchemy.engine.base.Engine select version()
# 2017-07-26 11:39:56,278 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:39:56,279 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2017-07-26 11:39:56,280 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:39:56,282 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2017-07-26 11:39:56,283 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:39:56,284 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2017-07-26 11:39:56,284 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:39:56,286 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2017-07-26 11:39:56,286 INFO sqlalchemy.engine.base.Engine {}
# 2017-07-26 11:39:56,287 INFO sqlalchemy.engine.base.Engine SELECT date, time, open, close, low, high, volume, pair."name"FROM candlestick, pair WHERE candlestick.pair_id = pair.id AND pair.id IN (SELECT pair.id FROM pair, exchange WHERE (SELECT pair.id FROM pair WHERE pair.name = 'USDT_ETH') = pair.alias_id AND pair.exchange_id = (SELECT exchange.id FROM exchange WHERE exchange."name" = 'poloniex')) ORDER BY candlestick.date;
# 2017-07-26 11:39:56,288 INFO sqlalchemy.engine.base.Engine {}
#            date      time        open       close         low    high  \
# 713  2017-07-21  07:00:00  226.886817  216.572720  210.000000  240.00
# 714  2017-07-22  07:00:00  216.572720  232.500000  215.360000  237.19
# 715  2017-07-23  07:00:00  233.000000  227.627775  218.077812  236.50
# 716  2017-07-24  07:00:00  227.700000  226.800000  224.000000  231.40
# 717  2017-07-25  07:00:00  226.800000  203.000000  190.000000  227.42
#
#            volume      name
# 713  3.354902e+07  USDT_ETH
# 714  2.068682e+07  USDT_ETH
# 715  1.720380e+07  USDT_ETH
# 716  8.850822e+06  USDT_ETH
# 717  3.942362e+07  USDT_ETH
#            date       close
# 712  2017-07-20  227.429900
# 713  2017-07-21  216.572720
# 714  2017-07-22  232.500000
# 715  2017-07-23  227.627775
# 716  2017-07-24  226.800000
# 3 Steps Ahead Forecast  is: [ 229.38832555  231.20958962  232.73156088]
