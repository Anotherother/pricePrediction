# %%
import get_data as get_data
import load_data as load
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import datetime 

from keras.callbacks import History 
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential, load_model, save_model
from keras import backend as K 

import time
from sklearn import metrics

import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 14, 8


import plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

init_notebook_mode(connected=True)

WINDOW = 22
# Out:
# Using TensorFlow backend.
# Couldn't import dot_parser, loading of dot files will not be possible.
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df = get_data.get_data_frame()

# %%
l = []
for i in range(int(df.shape[0]-14)):
    l.append(np.sum(df.volume.values[i:i+14]))
l = np.array(l)

# %%
from sklearn.preprocessing import MinMaxScaler

volumeSk = MinMaxScaler()
volumeDif  = pd.DataFrame(l).diff(1)
volumeDif = volumeSk.fit_transform(volumeDif.dropna().values)

closeSk = MinMaxScaler()
close = df.close
close = closeSk.fit_transform(close.values.reshape(-1,1))

# %%
VolumeDF = go.Scatter( y = volumeDif.reshape(-1,), name = 'VolumeDF')
closeDF = go.Scatter( y = close.reshape(-1,), name = 'CloseDF')

iplot([VolumeDF,closeDF])
# Out:
# <div id="3a56d7c8-04d7-4c07-9df2-67374cf7edac" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3a56d7c8-04d7-4c07-9df2-67374cf7edac", [{"type": "scatter", "y": [0.49666314093489516, 0.4966628858629898, 0.49666181170536755, 0.4966495122652856, 0.49663550731950307, 0.49665073071804927, 0.49664770384798057, 0.4966591082748968, 0.49666116267590316, 0.49663704213719956, 0.4966344523813654, 0.49665651256768817, 0.49665222462256614, 0.4966646256902272, 0.4966581717453731, 0.49665690419138003, 0.49665721910562355, 0.4966549845458729, 0.49665757708943126, 0.49665899029910093, 0.49665826267528174, 0.4966549580262148, 0.49665594982028793, 0.4966516351479816, 0.49666231261157917, 0.4966558779643321, 0.49666150998248104, 0.49665350675669645, 0.496656439688703, 0.4966570420821658, 0.4966989611673981, 0.496692243
# ...

# %%
plt.plot(l)

# %%
minersStat = pd.read_csv('./data_research/miners-revenue.csv')
